# %% [markdown]
# # 1. Create the following data frames based on the format provided:
# ## Example: Vis = [“Name”, “Gender”, “Track”, “Math<70”]; hometown is constant as Visayas

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Board2.csv')

# Display the dataframe
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
# Filter specific data based on conditions (Hometown = Visayas, Math = < 70)
df.loc[(df['Hometown']=='Visayas')&(df['Math']<70),['Name','Gender','Track','Math']]
# Out:
#    Name  Gender            Track  Math
# 3    S4    Male  Instrumentation    65
# 10  S11  Female    Communication    48
# 21  S22  Female    Communication    64

# %% [markdown]
# # a. Filename: Instru = [“Name”, “GEAS”, “Electronics >70”]; where track is constant as Instrumentation and hometown Luzon

# %%
# Filter specific data based on conditions (Track = Instrumentation, Hometown = Luzon) and save to 'Instru'
Instru = bd.loc[((bd['Electronics']) >70)&(bd['Track']=='Instrumentation')&(bd['Hometown']=='Luzon'), ['Name', 'GEAS', 'Electronics']]

# Save the filtered subset to a CSV file
Instru.to_csv('Instru.csv')
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %% [markdown]
# # b. Filename: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is constant as Mindanao and gender Female

# %%
# Calculate the average score across specified subjects
average = df[['Math','Electronics','GEAS','Communication']].mean(axis=1)
df['Average']=average

# Filter the DataFrame to find female students from 'Mindanao' with an average score
Mindy = df.loc[(df['Hometown']=='Mindanao')&(average)&(df['Gender']=='Female'),['Name','Track','Electronics','Average']]

# Save the filtered subset to a CSV file
Mindy.to_csv('Mindy.csv')
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %% [markdown]
# # 2. Create a visualization that shows how the different features contributes to average grade. Does chosen track in college, gender, or hometown contributes to a higher average score?

# %%
import matplotlib.pyplot as plt

# Create a bar chart to visualize average scores by 'Track'
plt.bar(df['Track'], average)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# Those in Microelectronics Tracks tend to have higher average compared with Instrumentation and Comunnication

# %%
# Create a bar chart to visualize average scores by 'Gender'
plt.bar(df['Gender'], average)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# Females have higher average compared to Males

# %%
# Create a bar chart to visualize average scores by 'Hometown'
plt.bar(df['Hometown'], average)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# Those who are residing in Luzon tend to have higher average compared to those who are residing in Mindanao and Visayas
